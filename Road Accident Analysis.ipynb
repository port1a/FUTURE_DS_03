# %%
# Importing libraries

import pandas as pd

# %%
df = pd.read_excel("Road Accident Data.xlsx")

# %%
df.head()
# Out:
#   Accident_Index Accident Date Day_of_Week          Junction_Control  \
# 0      BS0000001    2021-01-01    Thursday  Give way or uncontrolled
# 1      BS0000002    2021-01-05      Monday  Give way or uncontrolled
# 2      BS0000003    2021-01-04      Sunday  Give way or uncontrolled
# 3      BS0000004    2021-01-05      Monday       Auto traffic signal
# 4      BS0000005    2021-01-06     Tuesday       Auto traffic signal
#
#            Junction_Detail Accident_Severity   Latitude  \
# 0  T or staggered junction           Serious  51.512273
# 1               Crossroads           Serious  51.514399
# 2  T or staggered junction            Slight  51.486668
# 3  T or staggered junction           Serious  51.507804
# 4               Crossroads           Serious  51.482076
#
#         Light_Conditions Local_Authority_(District) Carriageway_Hazards  ...  \
# 0               Daylight     Kensington and Chelsea                 NaN  ...
# 1               Daylight     Kensington and Chelsea                 NaN  ...
# 2               Daylight     Kensington and Chelsea                 NaN  ...
# 3               Daylight     Kensington and Chelsea                 NaN  ...
# 4  Darkness - lights lit     Kensington and Chelsea                 NaN  ...
#
#    Number_of_Casualties  Number_of_Vehicles         Police_Force  \
# 0                     1                   2  Metropolitan Police
# 1                    11                   2  Metropolitan Police
# 2                     1                   2  Metropolitan Police
# 3                     1                   2  Metropolitan Police
# 4                     1                   2  Metropolitan Police
#
#   Road_Surface_Conditions           Road_Type Speed_limit      Time  \
# 0                     Dry      One way street          30  15:11:00
# 1             Wet or damp  Single carriageway          30  10:59:00
# 2                     Dry  Single carriageway          30  14:19:00
# 3            Frost or ice  Single carriageway          30  08:10:00
# 4                     Dry  Single carriageway          30  17:25:00
#
#   Urban_or_Rural_Area  Weather_Conditions           Vehicle_Type
# 0               Urban  Fine no high winds                    Car
# 1               Urban  Fine no high winds  Taxi/Private hire car
# 2               Urban  Fine no high winds  Taxi/Private hire car
# 3               Urban               Other  Motorcycle over 500cc
# 4               Urban  Fine no high winds                    Car
#
# [5 rows x 21 columns]

# %%
df.describe(include = 'all').T
# Out:
#                                count  unique  \
# Accident_Index                307973  307973
# Accident Date                 307973     NaN
# Day_of_Week                   307973       7
# Junction_Control              307973       7
# Junction_Detail               307973       9
# Accident_Severity             307973       4
# Latitude                    307973.0     NaN
# Light_Conditions              307973       5
# Local_Authority_(District)    307973     422
# Carriageway_Hazards             5424       5
# Longitude                   307973.0     NaN
# Number_of_Casualties        307973.0     NaN
# Number_of_Vehicles          307973.0     NaN
# Police_Force                  307973      51
# Road_Surface_Conditions       307973       5
# Road_Type                     307973       5
# Speed_limit                 307973.0     NaN
# Time                          307956    1439
# Urban_or_Rural_Area           307973       2
# Weather_Conditions            307973       8
# Vehicle_Type                  307973      15
#
#                                                             top    freq  \
# Accident_Index                                        BS0307973       1
# Accident Date                                               NaN     NaN
# Day_of_Week                                              Friday   50529
# Junction_Control                       Give way or uncontrolled  150045
# Junction_Detail             Not at junction or within 20 metres  123094
# Accident_Severity                                        Slight  263280
# Latitude                                                    NaN     NaN
# Light_Conditions                                       Daylight  227286
# Local_Authority_(District)                           Birmingham    6165
# Carriageway_Hazards                        Other object on road    2243
# Longitude                                                   NaN     NaN
# Number_of_Casualties                                        NaN     NaN
# Number_of_Vehicles                                          NaN     NaN
# Police_Force                                Metropolitan Police   46789
# Road_Surface_Conditions                                     Dry  208967
# Road_Type                                    Single carriageway  230612
# Speed_limit                                                 NaN     NaN
# Time                                                   17:00:00    2933
# Urban_or_Rural_Area                                       Urban  198532
# Weather_Conditions                           Fine no high winds  244496
# Vehicle_Type                                                Car  239794
#
#                                                      mean  \
# Accident_Index                                        NaN
# Accident Date               2021-12-23 22:19:39.804722944
# Day_of_Week                                           NaN
# Junction_Control                                      NaN
# Junction_Detail                                       NaN
# Accident_Severity                                     NaN
# Latitude                                        52.487005
# Light_Conditions                                      NaN
# Local_Authority_(District)                            NaN
# Carriageway_Hazards                                   NaN
# Longitude                                       -1.368884
# Number_of_Casualties                             1.356882
# Number_of_Vehicles                               1.829063
# Police_Force                                          NaN
# Road_Surface_Conditions                               NaN
# Road_Type                                             NaN
# Speed_limit                                     38.866037
# Time                                                  NaN
# Urban_or_Rural_Area                                   NaN
# Weather_Conditions                                    NaN
# Vehicle_Type                                          NaN
#
#                                             min                  25%  \
# Accident_Index                              NaN                  NaN
# Accident Date               2021-01-01 00:00:00  2021-06-28 00:00:00
# Day_of_Week                                 NaN                  NaN
# Junction_Control                            NaN                  NaN
# Junction_Detail                             NaN                  NaN
# Accident_Severity                           NaN                  NaN
# Latitude                              49.914488            51.485248
# Light_Conditions                            NaN                  NaN
# Local_Authority_(District)                  NaN                  NaN
# Carriageway_Hazards                         NaN                  NaN
# Longitude                             -7.516225            -2.247937
# Number_of_Casualties                        1.0                  1.0
# Number_of_Vehicles                          1.0                  1.0
# Police_Force                                NaN                  NaN
# Road_Surface_Conditions                     NaN                  NaN
# Road_Type                                   NaN                  NaN
# Speed_limit                                10.0                 30.0
# Time                                        NaN                  NaN
# Urban_or_Rural_Area                         NaN                  NaN
# Weather_Conditions                          NaN                  NaN
# Vehicle_Type                                NaN                  NaN
#
#                                             50%                  75%  \
# Accident_Index                              NaN                  NaN
# Accident Date               2021-12-08 00:00:00  2022-06-25 00:00:00
# Day_of_Week                                 NaN                  NaN
# Junction_Control                            NaN                  NaN
# Junction_Detail                             NaN                  NaN
# Accident_Severity                           NaN                  NaN
# Latitude                              52.225943            53.415517
# Light_Conditions                            NaN                  NaN
# Local_Authority_(District)                  NaN                  NaN
# Carriageway_Hazards                         NaN                  NaN
# Longitude                             -1.349258             -0.20681
# Number_of_Casualties                        1.0                  1.0
# Number_of_Vehicles                          2.0                  2.0
# Police_Force                                NaN                  NaN
# Road_Surface_Conditions                     NaN                  NaN
# Road_Type                                   NaN                  NaN
# Speed_limit                                30.0                 50.0
# Time                                        NaN                  NaN
# Urban_or_Rural_Area                         NaN                  NaN
# Weather_Conditions                          NaN                  NaN
# Vehicle_Type                                NaN                  NaN
#
#                                             max        std
# Accident_Index                              NaN        NaN
# Accident Date               2022-12-31 00:00:00        NaN
# Day_of_Week                                 NaN        NaN
# Junction_Control                            NaN        NaN
# Junction_Detail                             NaN        NaN
# Accident_Severity                           NaN        NaN
# Latitude                              60.598055   1.339011
# Light_Conditions                            NaN        NaN
# Local_Authority_(District)                  NaN        NaN
# Carriageway_Hazards                         NaN        NaN
# Longitude                              1.759398   1.356092
# Number_of_Casualties                       48.0   0.815857
# Number_of_Vehicles                         32.0   0.710477
# Police_Force                                NaN        NaN
# Road_Surface_Conditions                     NaN        NaN
# Road_Type                                   NaN        NaN
# Speed_limit                                70.0  14.032933
# Time                                        NaN        NaN
# Urban_or_Rural_Area                         NaN        NaN
# Weather_Conditions                          NaN        NaN
# Vehicle_Type                                NaN        NaN

# %%
df['Junction_Control'].value_counts()
# Out:
# Junction_Control
# Give way or uncontrolled               150045
# Data missing or out of range            98056
# Auto traffic signal                     32256
# Not at junction or within 20 metres     25378
# Stop sign                                1685
# Authorised person                         460
# Auto traffic sigl                          93
# Name: count, dtype: int64

# %%
df.select_dtypes(object).columns
# Out:
# Index(['Accident_Index', 'Day_of_Week', 'Junction_Control', 'Junction_Detail',
#        'Accident_Severity', 'Light_Conditions', 'Local_Authority_(District)',
#        'Carriageway_Hazards', 'Police_Force', 'Road_Surface_Conditions',
#        'Road_Type', 'Time', 'Urban_or_Rural_Area', 'Weather_Conditions',
#        'Vehicle_Type'],
#       dtype='object')

# %%
df['Light_Conditions'].unique()
# Out:
# array(['Daylight', 'Darkness - lights lit', 'Darkness - lighting unknown',
#        'Darkness - lights unlit', 'Darkness - no lighting'], dtype=object)
